# %%
import time
import requests
import json
from web3 import Web3
from web3 import _utils # for error handling
from multiprocessing.pool import ThreadPool

import pandas as pd

# saving dictionaries and pd dataFrames
import pickle
def save_obj(obj, name):
    with open(name+'.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name):
    with open(name+'.pkl', 'rb') as f:
        return pickle.load(f)

# %%
# get api key from https://dashboard.alchemy.com/
apiKey=""

# %%
# token info
# abis from etherscan
ens_nft_address = Web3.toChecksumAddress("0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85")
ens_nft_abi = '[{"inputs":[{"internalType":"contract ENS","name":"_ens","type":"address"},{"internalType":"bytes32","name":"_baseNode","type":"bytes32"}],"payable":false,"stateMutability":"nonpayable","type":"constructor"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"owner","type":"address"},{"indexed":true,"internalType":"address","name":"approved","type":"address"},{"indexed":true,"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"Approval","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"owner","type":"address"},{"indexed":true,"internalType":"address","name":"operator","type":"address"},{"indexed":false,"internalType":"bool","name":"approved","type":"bool"}],"name":"ApprovalForAll","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"controller","type":"address"}],"name":"ControllerAdded","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"controller","type":"address"}],"name":"ControllerRemoved","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"uint256","name":"id","type":"uint256"},{"indexed":true,"internalType":"address","name":"owner","type":"address"},{"indexed":false,"internalType":"uint256","name":"expires","type":"uint256"}],"name":"NameMigrated","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"uint256","name":"id","type":"uint256"},{"indexed":true,"internalType":"address","name":"owner","type":"address"},{"indexed":false,"internalType":"uint256","name":"expires","type":"uint256"}],"name":"NameRegistered","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"uint256","name":"id","type":"uint256"},{"indexed":false,"internalType":"uint256","name":"expires","type":"uint256"}],"name":"NameRenewed","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"previousOwner","type":"address"},{"indexed":true,"internalType":"address","name":"newOwner","type":"address"}],"name":"OwnershipTransferred","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"from","type":"address"},{"indexed":true,"internalType":"address","name":"to","type":"address"},{"indexed":true,"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"Transfer","type":"event"},{"constant":true,"inputs":[],"name":"GRACE_PERIOD","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"controller","type":"address"}],"name":"addController","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"to","type":"address"},{"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"approve","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"internalType":"uint256","name":"id","type":"uint256"}],"name":"available","outputs":[{"internalType":"bool","name":"","type":"bool"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"internalType":"address","name":"owner","type":"address"}],"name":"balanceOf","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[],"name":"baseNode","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"internalType":"address","name":"","type":"address"}],"name":"controllers","outputs":[{"internalType":"bool","name":"","type":"bool"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[],"name":"ens","outputs":[{"internalType":"contract ENS","name":"","type":"address"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"getApproved","outputs":[{"internalType":"address","name":"","type":"address"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"internalType":"address","name":"owner","type":"address"},{"internalType":"address","name":"operator","type":"address"}],"name":"isApprovedForAll","outputs":[{"internalType":"bool","name":"","type":"bool"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[],"name":"isOwner","outputs":[{"internalType":"bool","name":"","type":"bool"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"internalType":"uint256","name":"id","type":"uint256"}],"name":"nameExpires","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[],"name":"owner","outputs":[{"internalType":"address","name":"","type":"address"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"ownerOf","outputs":[{"internalType":"address","name":"","type":"address"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"internalType":"uint256","name":"id","type":"uint256"},{"internalType":"address","name":"owner","type":"address"}],"name":"reclaim","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"uint256","name":"id","type":"uint256"},{"internalType":"address","name":"owner","type":"address"},{"internalType":"uint256","name":"duration","type":"uint256"}],"name":"register","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"uint256","name":"id","type":"uint256"},{"internalType":"address","name":"owner","type":"address"},{"internalType":"uint256","name":"duration","type":"uint256"}],"name":"registerOnly","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"controller","type":"address"}],"name":"removeController","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"uint256","name":"id","type":"uint256"},{"internalType":"uint256","name":"duration","type":"uint256"}],"name":"renew","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[],"name":"renounceOwnership","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"from","type":"address"},{"internalType":"address","name":"to","type":"address"},{"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"safeTransferFrom","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"from","type":"address"},{"internalType":"address","name":"to","type":"address"},{"internalType":"uint256","name":"tokenId","type":"uint256"},{"internalType":"bytes","name":"_data","type":"bytes"}],"name":"safeTransferFrom","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"to","type":"address"},{"internalType":"bool","name":"approved","type":"bool"}],"name":"setApprovalForAll","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"resolver","type":"address"}],"name":"setResolver","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"internalType":"bytes4","name":"interfaceID","type":"bytes4"}],"name":"supportsInterface","outputs":[{"internalType":"bool","name":"","type":"bool"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"from","type":"address"},{"internalType":"address","name":"to","type":"address"},{"internalType":"uint256","name":"tokenId","type":"uint256"}],"name":"transferFrom","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"internalType":"address","name":"newOwner","type":"address"}],"name":"transferOwnership","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"}]'

ens_token_address = Web3.toChecksumAddress("0xc18360217d8f7ab5e7c516566761ea12ce7f9d72")
ens_token_abi = '[{"inputs":[{"internalType":"uint256","name":"freeSupply","type":"uint256"},{"internalType":"uint256","name":"airdropSupply","type":"uint256"},{"internalType":"uint256","name":"_claimPeriodEnds","type":"uint256"}],"stateMutability":"nonpayable","type":"constructor"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"owner","type":"address"},{"indexed":true,"internalType":"address","name":"spender","type":"address"},{"indexed":false,"internalType":"uint256","name":"value","type":"uint256"}],"name":"Approval","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"claimant","type":"address"},{"indexed":false,"internalType":"uint256","name":"amount","type":"uint256"}],"name":"Claim","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"delegator","type":"address"},{"indexed":true,"internalType":"address","name":"fromDelegate","type":"address"},{"indexed":true,"internalType":"address","name":"toDelegate","type":"address"}],"name":"DelegateChanged","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"delegate","type":"address"},{"indexed":false,"internalType":"uint256","name":"previousBalance","type":"uint256"},{"indexed":false,"internalType":"uint256","name":"newBalance","type":"uint256"}],"name":"DelegateVotesChanged","type":"event"},{"anonymous":false,"inputs":[{"indexed":false,"internalType":"bytes32","name":"merkleRoot","type":"bytes32"}],"name":"MerkleRootChanged","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"previousOwner","type":"address"},{"indexed":true,"internalType":"address","name":"newOwner","type":"address"}],"name":"OwnershipTransferred","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"address","name":"from","type":"address"},{"indexed":true,"internalType":"address","name":"to","type":"address"},{"indexed":false,"internalType":"uint256","name":"value","type":"uint256"}],"name":"Transfer","type":"event"},{"inputs":[],"name":"DOMAIN_SEPARATOR","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"owner","type":"address"},{"internalType":"address","name":"spender","type":"address"}],"name":"allowance","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"spender","type":"address"},{"internalType":"uint256","name":"amount","type":"uint256"}],"name":"approve","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"account","type":"address"}],"name":"balanceOf","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"account","type":"address"},{"internalType":"uint32","name":"pos","type":"uint32"}],"name":"checkpoints","outputs":[{"components":[{"internalType":"uint32","name":"fromBlock","type":"uint32"},{"internalType":"uint224","name":"votes","type":"uint224"}],"internalType":"struct ERC20Votes.Checkpoint","name":"","type":"tuple"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"claimPeriodEnds","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"uint256","name":"amount","type":"uint256"},{"internalType":"address","name":"delegate","type":"address"},{"internalType":"bytes32[]","name":"merkleProof","type":"bytes32[]"}],"name":"claimTokens","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[],"name":"decimals","outputs":[{"internalType":"uint8","name":"","type":"uint8"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"spender","type":"address"},{"internalType":"uint256","name":"subtractedValue","type":"uint256"}],"name":"decreaseAllowance","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"delegatee","type":"address"}],"name":"delegate","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"delegatee","type":"address"},{"internalType":"uint256","name":"nonce","type":"uint256"},{"internalType":"uint256","name":"expiry","type":"uint256"},{"internalType":"uint8","name":"v","type":"uint8"},{"internalType":"bytes32","name":"r","type":"bytes32"},{"internalType":"bytes32","name":"s","type":"bytes32"}],"name":"delegateBySig","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"account","type":"address"}],"name":"delegates","outputs":[{"internalType":"address","name":"","type":"address"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"uint256","name":"blockNumber","type":"uint256"}],"name":"getPastTotalSupply","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"account","type":"address"},{"internalType":"uint256","name":"blockNumber","type":"uint256"}],"name":"getPastVotes","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"account","type":"address"}],"name":"getVotes","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"spender","type":"address"},{"internalType":"uint256","name":"addedValue","type":"uint256"}],"name":"increaseAllowance","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"uint256","name":"index","type":"uint256"}],"name":"isClaimed","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"merkleRoot","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"minimumMintInterval","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"dest","type":"address"},{"internalType":"uint256","name":"amount","type":"uint256"}],"name":"mint","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[],"name":"mintCap","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"name","outputs":[{"internalType":"string","name":"","type":"string"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"nextMint","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"owner","type":"address"}],"name":"nonces","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"account","type":"address"}],"name":"numCheckpoints","outputs":[{"internalType":"uint32","name":"","type":"uint32"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"owner","outputs":[{"internalType":"address","name":"","type":"address"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"owner","type":"address"},{"internalType":"address","name":"spender","type":"address"},{"internalType":"uint256","name":"value","type":"uint256"},{"internalType":"uint256","name":"deadline","type":"uint256"},{"internalType":"uint8","name":"v","type":"uint8"},{"internalType":"bytes32","name":"r","type":"bytes32"},{"internalType":"bytes32","name":"s","type":"bytes32"}],"name":"permit","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[],"name":"renounceOwnership","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"bytes32","name":"_merkleRoot","type":"bytes32"}],"name":"setMerkleRoot","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"dest","type":"address"}],"name":"sweep","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[],"name":"symbol","outputs":[{"internalType":"string","name":"","type":"string"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"totalSupply","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"recipient","type":"address"},{"internalType":"uint256","name":"amount","type":"uint256"}],"name":"transfer","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"sender","type":"address"},{"internalType":"address","name":"recipient","type":"address"},{"internalType":"uint256","name":"amount","type":"uint256"}],"name":"transferFrom","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"newOwner","type":"address"}],"name":"transferOwnership","outputs":[],"stateMutability":"nonpayable","type":"function"}]'

ens_dao_treasury_address =  Web3.toChecksumAddress("0xfe89cc7abb2c4183683ab71653c4cdc9b02d44b7")
ens_dao_treasury_abi = '[{"inputs":[{"internalType":"uint256","name":"minDelay","type":"uint256"},{"internalType":"address[]","name":"proposers","type":"address[]"},{"internalType":"address[]","name":"executors","type":"address[]"}],"stateMutability":"nonpayable","type":"constructor"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes32","name":"id","type":"bytes32"},{"indexed":true,"internalType":"uint256","name":"index","type":"uint256"},{"indexed":false,"internalType":"address","name":"target","type":"address"},{"indexed":false,"internalType":"uint256","name":"value","type":"uint256"},{"indexed":false,"internalType":"bytes","name":"data","type":"bytes"}],"name":"CallExecuted","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes32","name":"id","type":"bytes32"},{"indexed":true,"internalType":"uint256","name":"index","type":"uint256"},{"indexed":false,"internalType":"address","name":"target","type":"address"},{"indexed":false,"internalType":"uint256","name":"value","type":"uint256"},{"indexed":false,"internalType":"bytes","name":"data","type":"bytes"},{"indexed":false,"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"indexed":false,"internalType":"uint256","name":"delay","type":"uint256"}],"name":"CallScheduled","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"Cancelled","type":"event"},{"anonymous":false,"inputs":[{"indexed":false,"internalType":"uint256","name":"oldDuration","type":"uint256"},{"indexed":false,"internalType":"uint256","name":"newDuration","type":"uint256"}],"name":"MinDelayChange","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes32","name":"role","type":"bytes32"},{"indexed":true,"internalType":"bytes32","name":"previousAdminRole","type":"bytes32"},{"indexed":true,"internalType":"bytes32","name":"newAdminRole","type":"bytes32"}],"name":"RoleAdminChanged","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes32","name":"role","type":"bytes32"},{"indexed":true,"internalType":"address","name":"account","type":"address"},{"indexed":true,"internalType":"address","name":"sender","type":"address"}],"name":"RoleGranted","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"internalType":"bytes32","name":"role","type":"bytes32"},{"indexed":true,"internalType":"address","name":"account","type":"address"},{"indexed":true,"internalType":"address","name":"sender","type":"address"}],"name":"RoleRevoked","type":"event"},{"inputs":[],"name":"DEFAULT_ADMIN_ROLE","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"EXECUTOR_ROLE","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"PROPOSER_ROLE","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"TIMELOCK_ADMIN_ROLE","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"cancel","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"target","type":"address"},{"internalType":"uint256","name":"value","type":"uint256"},{"internalType":"bytes","name":"data","type":"bytes"},{"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"internalType":"bytes32","name":"salt","type":"bytes32"}],"name":"execute","outputs":[],"stateMutability":"payable","type":"function"},{"inputs":[{"internalType":"address[]","name":"targets","type":"address[]"},{"internalType":"uint256[]","name":"values","type":"uint256[]"},{"internalType":"bytes[]","name":"datas","type":"bytes[]"},{"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"internalType":"bytes32","name":"salt","type":"bytes32"}],"name":"executeBatch","outputs":[],"stateMutability":"payable","type":"function"},{"inputs":[],"name":"getMinDelay","outputs":[{"internalType":"uint256","name":"duration","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"role","type":"bytes32"}],"name":"getRoleAdmin","outputs":[{"internalType":"bytes32","name":"","type":"bytes32"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"getTimestamp","outputs":[{"internalType":"uint256","name":"timestamp","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"role","type":"bytes32"},{"internalType":"address","name":"account","type":"address"}],"name":"grantRole","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"bytes32","name":"role","type":"bytes32"},{"internalType":"address","name":"account","type":"address"}],"name":"hasRole","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"target","type":"address"},{"internalType":"uint256","name":"value","type":"uint256"},{"internalType":"bytes","name":"data","type":"bytes"},{"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"internalType":"bytes32","name":"salt","type":"bytes32"}],"name":"hashOperation","outputs":[{"internalType":"bytes32","name":"hash","type":"bytes32"}],"stateMutability":"pure","type":"function"},{"inputs":[{"internalType":"address[]","name":"targets","type":"address[]"},{"internalType":"uint256[]","name":"values","type":"uint256[]"},{"internalType":"bytes[]","name":"datas","type":"bytes[]"},{"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"internalType":"bytes32","name":"salt","type":"bytes32"}],"name":"hashOperationBatch","outputs":[{"internalType":"bytes32","name":"hash","type":"bytes32"}],"stateMutability":"pure","type":"function"},{"inputs":[{"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"isOperation","outputs":[{"internalType":"bool","name":"pending","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"isOperationDone","outputs":[{"internalType":"bool","name":"done","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"isOperationPending","outputs":[{"internalType":"bool","name":"pending","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"id","type":"bytes32"}],"name":"isOperationReady","outputs":[{"internalType":"bool","name":"ready","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"bytes32","name":"role","type":"bytes32"},{"internalType":"address","name":"account","type":"address"}],"name":"renounceRole","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"bytes32","name":"role","type":"bytes32"},{"internalType":"address","name":"account","type":"address"}],"name":"revokeRole","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"target","type":"address"},{"internalType":"uint256","name":"value","type":"uint256"},{"internalType":"bytes","name":"data","type":"bytes"},{"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"internalType":"bytes32","name":"salt","type":"bytes32"},{"internalType":"uint256","name":"delay","type":"uint256"}],"name":"schedule","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address[]","name":"targets","type":"address[]"},{"internalType":"uint256[]","name":"values","type":"uint256[]"},{"internalType":"bytes[]","name":"datas","type":"bytes[]"},{"internalType":"bytes32","name":"predecessor","type":"bytes32"},{"internalType":"bytes32","name":"salt","type":"bytes32"},{"internalType":"uint256","name":"delay","type":"uint256"}],"name":"scheduleBatch","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"bytes4","name":"interfaceId","type":"bytes4"}],"name":"supportsInterface","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"uint256","name":"newDelay","type":"uint256"}],"name":"updateDelay","outputs":[],"stateMutability":"nonpayable","type":"function"},{"stateMutability":"payable","type":"receive"}]'

# %%
# connect to an alchemy ethereum node
alchemy_url = f"https://eth-mainnet.g.alchemy.com/v2/{apiKey}"
w3 = Web3(Web3.HTTPProvider(alchemy_url))
print(w3.isConnected())
# Out:
# True

# %%
# reading data from ens contracts...
ens_token_contract = w3.eth.contract(address = ens_token_address, abi = ens_token_abi)
ens_nft_contract = w3.eth.contract(address = ens_nft_address, abi = ens_nft_abi)
end_dao_treasury_wallet = w3.eth.contract(address = ens_dao_treasury_address, abi = ens_dao_treasury_abi)

# %%
# get transfers to an address?
# https://ethereum.stackexchange.com/questions/80135/getting-tokens-transferred-from-web3-py?rq=1

# %%
# w3.eth.get_block('latest')

# %%
# get contract events!! 
# but the relevant info from these is largely in alchemy's nft info method
# https://web3py.readthedocs.io/en/stable/contracts.html?highlight=decode%20transaction%20abi#events
# - registrations
# - renewals
# logs = ens_nft_contract.events.NameRegistered().getLogs(fromBlock= 15636207-100, toBlock= 15636207)
# ens_nft_contract.events.NameRenewed()

# # too general
# # web3.eth.get_logs(event_filter_params)
# fltr = w3.eth.filter({'fromBlock': 15636207-100, 'toBlock': 15636207, 'address': f'{ens_nft_address}'})
# tmp = w3.eth.get_filter_logs(fltr.filter_id)
# # if I can get all contract transactions --
# # w3.eth.get_transaction(tx_hash)

# %%
# tx_hash = logs[-1].transactionHash
# tx = w3.eth.get_transaction(tx_hash)
# # this was a registration/minting
# # https://etherscan.io/tx/0x7f3bd853681c0f75a35f71bae631c2e2bb3bce58b6ad9a97b595eefcb9b99f8a
# # tx

# %%
# tx_receipt = w3.eth.get_transaction_receipt(tx_hash)

# %%
# ens_nft_contract.events.NameRegistered().processReceipt(tx_receipt)

# %%
# ens_nft_contract.all_functions
# ens_nft_contract.decode_function_input(tx.input)

# %%
# TODO: 
# check each alchamey function...

# - change token balances to=true? and see what is returned?

# - write function for getNFTsForCollection
# - process output of getNFTsForCollection


# revenue and income projections.. 
# revenue data from alchamey & knoeledge of registration costs;
# name_length, registration date, & expiration date can be used to estimate future revenue?
# assuming everyone re-registers at the same prices for the same duration ; 
# revenue = annual price|name_langth * (expiration date - registration date) in years

# estimate
# - new users / new registrations & project this with a regression model?
# - historical re-registration rate
# - quarterly profits from registrations, & from re-registrations?

# %%
# Alchamey requests api;

base_url = f"https://eth-mainnet.g.alchemy.com/nft/v2/{apiKey}"

# collection -> owners
def getOwnersForCollection():
    # docs: https://docs.alchemy.com/reference/getownersforcollection
    # first page
    first_page_url = base_url+ f"/getOwnersForCollection?contractAddress={ens_nft_address}&withTokenBalances=false"
    headers = {"accept": "application/json"}
    response = requests.get(first_page_url, headers=headers) 

    # response.json()['ownerAddresses'] is a list with len() usually around 50k
    owner_addresses_page = response.json()['ownerAddresses']
    owner_addresses_all = owner_addresses_page

    # subsequent pages (todo:add more conditions avoid infinite loops)
    while True:
        page_key_old = response.json()['pageKey']
        next_page_url = first_page_url + f"&pageKey={page_key_old}"
        response = requests.get(next_page_url, headers=headers) 
        owner_addresses_page = response.json()['ownerAddresses']
        owner_addresses_all+=owner_addresses_page
        print(len(owner_addresses_all),page_key_old) # feedback to monitor
        if 'pageKey' not in response.json():
            print('no more page keys')
            return owner_addresses_all

# owner -> NFTs owned
# https://docs.alchemy.com/reference/getnfts
def getNFTs(owner):
    first_page_url = base_url + f"/getNFTs?owner={owner}&contractAddresses[]={ens_nft_address}&withMetadata=true"
    headers = {"accept": "application/json"}
    response = requests.get(first_page_url, headers=headers)
    response_json = response.json()

    owner_nfts_all = response_json['ownedNfts']
    while len(owner_nfts_all) < response_json['totalCount']:
            page_key = response_json['pageKey']
            next_page_url = first_page_url + f"&pageKey={page_key}"
            response = requests.get(next_page_url, headers=headers) # introduces dupes bc of page size being 100, need to dedupe later
            response_json=response.json()
            owner_nfts_all += response_json['ownedNfts']
            print(f"{len(owner_nfts_all)} / {response_json['totalCount']}",page_key) # feedback to monitor

    return owner_nfts_all # may have dupes -- could dedupe by processing into a dict keyed by tokenId

def process_nft_list(nft_list):
    nfts_df = pd.DataFrame()
    for nft in nft_list:
        if 'metadata' in nft.keys():
            if 'attributes' in nft['metadata'].keys():
                if nft['metadata']['attributes']:
                    tmp_df=pd.DataFrame(nft['metadata']['attributes']).set_index('trait_type')
                    tmp_df=tmp_df.T.loc[['value']] # transpose for easier formatting
                else: tmp_df=pd.DataFrame()
            else: tmp_df=pd.DataFrame()
        else: tmp_df=pd.DataFrame()

        if 'title' in nft.keys(): 
            tmp_df['title'] = nft['title']
        else: tmp_df['title'] = None

        if 'id' in nft.keys():
            if 'tokenId' in nft['id'].keys():
                tmp_df['id'] = nft['id']['tokenId']
        else: tmp_df['id'] = None

        # if 'owner' in nft.keys():
        #     tmp_df['owner']=owner
        # else: tmp_df['owner']=owner

        nfts_df=nfts_df.append(tmp_df)

    nfts_df=nfts_df.drop_duplicates()
    return nfts_df

# process the list of nfts with metadata and dupes

# collection -> NFT info
# https://docs.alchemy.com/reference/getnftsforcollection
# skipped bc relevant info was returned by getNFTs
# # getNFTsForCollection
# url = f"https://eth-mainnet.g.alchemy.com/nft/v2/{apiKey}/getNFTsForCollection?contractAddress={ens_nft_address}&withMetadata=true"
# headers = {"accept": "application/json"}
# response = requests.get(url, headers=headers)

# NFT sales
# https://docs.alchemy.com/reference/getnftsales

# %% [markdown]
# ## Owners and domains owned

# %%
# get all owner addresses
owner_addresses_all = getOwnersForCollection()
# Out:
# 99999 0x16931dcaf34ef7f56fcb9d3e7b744d5a83768cc4
# 149998 0x2d9d86e44fbba4425915c94d931c183352b6303b
# 199997 0x44b609869b8a534bceb4a415f2a1153683303b60
# 249996 0x5bccf0703d7ab9d564e418c1fce34129cd631924
# 299993 0x72db98bd5cc641409ca1fd15628c5d6a29e4a7f5
# 349992 0x89dd92d2db90fcf049cfdc22f913f2dc89f1bac5
# 399992 0xa1364d6d3ed97159ad9afcafa56d9b077f2153a9
# 449992 0xb83216ce43714fdac527d809dfcd9dd07d11623a
# 499991 0xcf3fc0e5ea00912cbee4682f81330521327c5279
# 549990 0xe6321f3960e1ea812d2aa126d6ce268e0e7d4aee
# 555902 0xfd55df51b2150279a8bdabfab83cf28b57f5a9d8
# no more page keys

# %%
# check number of owners
len(owner_addresses_all) # = 554110, vs 554080 on etherscan https://etherscan.io/token/0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85#balances
# Out:
# 555902

# %%
# get all nfts owned by each owner & format into a pandas df
# df = pd.DataFrame()
df = pd.read_pickle('owners_and_their_nfts') # to start where this left off...
# i = 0
# i=12000 # last printed id
i=62096

# %%
def get_nft_lists(chunk):
    t1=time.time()
    i=0
    for owner_address in chunk:
        i+=1
        if owner_address == '0x000000000000000000000000000000000000dead': continue # skip dead address
        attempts = 0
        while attempts<3:
            try:
                nft_list = getNFTs(owner_address)
                path = f'owner_nfts_dicts/nfts_owned_by_{owner_address}'
                save_obj(nft_list, path)
                attempts=4 # just to exit the loop
            except: 
                time.sleep(.5)
                print(f'error with: {owner_address}, attempt: {attempts}')
                attempts+=1
    print(f'chunk done in {time.time()-t1}')
    return path

# %%
# left off around 67000

# parse owner addresses from file names
# owner_addresses_filteres = [a for a in owner_addresses_all if a not in (completed)]

ranges=[i for i in range(0,int(len(owner_addresses_filtered)),int(round(len(owner_addresses_filtered)/5550)))]
ranges.append(len(owner_addresses_filtered))

# get list of events to pass in each chunk
chunks = [owner_addresses_filtered[ranges[i]:ranges[i+1]] for i in range(len(ranges)-1)]

# %%
len(chunks)
# Out:
# 5560

# %%
len(chunks[0])
# Out:
# 100

# %%
pool = ThreadPool()

# %%
results = pool.map(get_nft_lists, chunks)

# %%
# tmp=get_nft_lists(chunks[0])
# Out:
# 101 / 101 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmVmN2FlMGQ2NDNkOGE0N2YzMGVlMmY1NzI4ZmJjMzA4OWQ2YjBkOWE4Njc5Yjk1MWY0YjJmY2JhZWE0NmQwMzpmYWxzZQ==
# error with: 0x0000000000000000000000000000000000000999, attempt: 0
# error with: 0x00000000000000000000000000000000deadbeef, attempt: 0
# error with: 0x000000000000a25d11d75bdd1ebf1397db20bbc1, attempt: 0
# error with: 0x0000000000078c65a676f9a1f2ae66db0cbdff48, attempt: 0
# error with: 0x000000000020a61d9ad9371a410c10eb699c78f4, attempt: 0
# error with: 0x00000000005ef87f8ca7014309ece7260bbcdaeb, attempt: 0
# error with: 0x0000000000d431ae074af8fbcbfa4d3ba2d6b435, attempt: 0
# error with: 0x000000000a38444e0a6e37d3b630d7e855a7cb13, attempt: 0
# error with: 0x000000000ee01fe9a502c1ee892a12c384f22a02, attempt: 0
# error with: 0x000000001d94b2612380854e74c32548d3ce4720, attempt: 0
# error with: 0x000000005e2f9f4a3056c1540b5235475bd17871, attempt: 0
# error with: 0x00000000b9d65fbedfe87673e8518452ae74a13b, attempt: 0
# chunk done in 54.32983589172363

# %%
# TODO: 
# - import pickle, 
# - save df so it can be accessed quickly later

# - for faster loop, save each wallet's df, then later concatinate them all.

while i <= len(owner_addresses_all): # looping over indecies makes it easier to continue where i left off if there is an error
    owner_address = owner_addresses_all[i]
    if i%500 == 0: 
        df.to_pickle(path = '/Users/macstrelioff/Documents/git/crypto_public/ENS NFT analyses/owners_and_their_nfts')
        print(f'{i} / {len(owner_addresses_all)}')
    if owner_address == '0x000000000000000000000000000000000000dead': continue # skip dead address
    try:
        nft_list = getNFTs(owner_address)
        nft_df = process_nft_list(nft_list) # dead address gave error
    except: 
        nft_df = pd.DataFrame()
    nft_df['owner']=owner_address
    df=df.append(nft_df)
    i+=1
    df=df.drop_duplicates()
# Out:
# 39000 / 554770
# 200 / 397 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDE1OTUwOTIxZjBkNTI3NGFlZmNkMWM0Y2U3N2UzNzAzMWZjYjkxYzQ4ZTI0Yjg4MjA4YjhjMDIwZTI3ODcxOTpmYWxzZQ==
# 300 / 397 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODNhY2Y5YjJmNTFhZDc2OTM5YjgwNmJlZjM5OTI1NmFiMzNkNmY1OTcwMDEwZjU3MGQ5ZTA1NDFiOGNmZmEyYjpmYWxzZQ==
# 397 / 397 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzU5M2IzMjU2NTA4MTBmOGUyZGRiYmMwMzA2Y2Y2ZTg0Y2NkNTQ4Y2RkNDY2NjAxMGFjMzBjOTM2ZmE5NjcxODpmYWxzZQ==
# 39500 / 554770
# 182 / 182 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4N2IxYWFjNDBmZjdiNjE5NjVlNTMzNDk2MjRjYWJjMTRkZjdhNGVlOWJlZmM4YmE4YWE4ZGU2NDFmNTY5ZDhlOTpmYWxzZQ==
# 40000 / 554770
# 200 / 274 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTY4MGFkZjdmZGUwYTU2MDM1MDI0NGRhZDUyNWE4NzI4OTMzOWNiMWEwYzA0YmUwZmViYTUxMDE1MmQ0OGJkZDpmYWxzZQ==
# 274 / 274 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Yjk5MTRmM2YzZjllNzBhMzRmYzY0OTkwZGMwODYxMjhlNDJkNGQ4NGEzNTI1NjZmMTIyMGUwMDE1NThlNTY3MzpmYWxzZQ==
# 107 / 107 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTk5YjFjODkxYzQ3NmNhODYxYThmOGU2N2QxOGUzZmE5MWY3MmJjMWNiZTM5NzQ5M2YyZDg3ZTdjZTM5MjkwMDpmYWxzZQ==
# 141 / 141 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjQ2NjdhYzg5ZDEzODFlYjg1Yzc4ZWRjZjE0ODIxNDM4YzUzMmI1MTMwNzQ5ZmRkMzBkZDFmNjIzYmY4MTE0OTpmYWxzZQ==
# 40500 / 554770
# 142 / 142 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWRkNzdjNmFjMTQ3NjY1NWQzMDdjN2FlMWQ3NjkyOTVhM2ZjYWEzNjU2NzliN2Q3MWZkMTFiODA0ZWNmZDdjODpmYWxzZQ==
# 200 / 361 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4M2I3ZmI0MzMwNWNkZjk0NWZlOTg0NGU3MGIwNjVhNGRiODNkNzJhYjdkZTI4Y2FlMDcwNjUwMzZjZTQ4NjBkZTpmYWxzZQ==
# 300 / 361 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODUzYTkzMDdlZTdmMmVmZTZlMTQ4MjI0ZmJiM2YxMzQ4ZWFjNjhjZGMzNDkzZWNkYzYxOWEwZjRiNmZiYWQ2NDpmYWxzZQ==
# 361 / 361 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGFhOTE5N2Y0NmI3ZGI0OWY5MzZlMDYwYTY5ZTNhN2Q3ZTVkNGE1NjkxYTE5OTA1MWZmOTliN2JlMjIyNzNkZjpmYWxzZQ==
# 117 / 117 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzQ3NWQ2NWQ4MjA2YmRmNzMwZWMyZGE5MzQ1MjQwNDYyYjE0OTJjMmI4MDEyMTE3MzgzODkwM2IyMGMwMDY1ZjpmYWxzZQ==
# 41000 / 554770
# 103 / 103 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmM2NTkyNzU2N2I1MjliNjJiNTI5MzU0ZDk5MTc3YzhiNjQxYjhkYTgxYmI3Yzg2MTZjYTg5NjIzZTk1YjkzYjpmYWxzZQ==
# 138 / 138 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Yzc5Zjc5NzRlMzgzZTQxOGYwZDA4Y2QzNjNiOWY3ZDYwMjI2NGQ4NmFkNmQyOWZlZGI4Yjc4ODA5OGM0ZjgwNDpmYWxzZQ==
# 200 / 239 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzdiYzgwZWNiM2IyYTRlNmU0NDI0YjJhZTg1YzIyMTg1Y2ZiNjE0OTcwZjc3Mjc0ZWI0MjAzMjAzMDQ1NzhjNzpmYWxzZQ==
# 239 / 239 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDliMGQxZWM5NDczNmM1NmY2YzU4MjcxN2VmNjI4MjA5YjU3ZTI0NDJmN2MyNGIyYTgxOTBiOWVkMWZjZTVmMTpmYWxzZQ==
# 41500 / 554770
# 200 / 248 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmZhNWIzMmE0ZjBmNDI4MmE1MTZiNjNhZmEyNjhhNmI5ZTYwNWQxN2E5YjMwM2I5ZWM4ZmE1ZDU5MjY2ODZjMTpmYWxzZQ==
# 248 / 248 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzhjMjMzODQ0NjE0ZGZmZmRkNTFhMWY2NWYzMmIxNjFkNmVmOTNjOGI2MGFiYjhhZGM2MzNhNDViMTFmZjhmODpmYWxzZQ==
# 180 / 180 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGJlNjUxMGRkNzIxYzAxYjkxYjJlMTQxOTFjOWVkZGRjYTZlMGQyZGJiOGFhNDllMzM4MzY1MWY2ZThiYTk4OTpmYWxzZQ==
# 200 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MWJlMjA2NWZiNzQ2ZGU4YzEzMzdmNTRjNDM5NjEyM2Y1NjU4NDIyOTc1NTcxN2I5MjhjZTU5ZGE4OWQ4MjkzNTpmYWxzZQ==
# 300 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MzQ3ZTc0ZTg2OGNiMjk3MmVlYTgwMzgwN2M4MjJkYjNkMmVmMzE1NmRiZmQ1MzFlOTQ2NmVkMTg0ZGM3YTNmMDpmYWxzZQ==
# 400 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTFiMWEyMmYzMGExODg4NTg1MDAxN2Q5Y2U2OWJjNWJmZGM0Y2FhN2U0YmU3ZjZmMTc3NDI1OTRmYWM0MWJlZTpmYWxzZQ==
# 500 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmYyZjg0NWY1ZGIwOTY2ZWYzMjVmZjQ3MzA2OGM4NTllZDdmYWFiNDJlNTcxZWFiNTFlY2FjNDg0Y2I3YjgzNjpmYWxzZQ==
# 600 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODhjMmQ0NzMxZDVhMGRjNjhiYjY2ZTViYmE0MDVhNTI0YzAwNTgwZWM3YTQzZWM4YjBmZjcxNTQ0NjVhYmRjZDpmYWxzZQ==
# 700 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTYyNzU2OTBjNzJkZTEzMDVhMGQ5YjI0Yzg3ZGRlMGVjMzA0OTgwNTU0MGMzMjYxOTQzZTEyZWQxYjcxYjEyZDpmYWxzZQ==
# 800 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzViYjcyYjI0ZmE2NGQwNDlkM2JhNDQ3NGU2NmNlNDkwZGIyYjY3ZTNjMjEwOGYzOTNhYzEzZDQ2ZWNmZDBmZTpmYWxzZQ==
# 900 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGMyOWZlOGNjYTk4NWJmZTVmNDNlOGI0ZjM3MzQ5ZjExNTZhY2YwMGEzNmVkNzlmYzA4YjIyOTdjZjllMWZlMTpmYWxzZQ==
# 932 / 932 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjgyNzIxNjI4YjhmZTdjNGVhZGQ1ZmU0NDZmOWM2ZmI1MjRhNjk1ZjVmZmQwOGIwNzk5MGRiYWI5MDkzN2I2YzpmYWxzZQ==
# 133 / 133 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2NkMDZjNGZkZjFhODc3ZWY2ZGNmNTA5YTQ0M2FlZDRmYzRmNjhmYjQ1Njk4ZmVhNjg5OTBlZjgxOTEyMzAzZjpmYWxzZQ==
# 139 / 139 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTI1ODUwODE0YzVhZDAyMDJlNjBhYjdkY2I5ODk5MGQ5MDZlYjczNWRmOGFjMGE4ODliY2Q5NjJlMzA5ZjljMTpmYWxzZQ==
# 155 / 155 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTg4MjA5MDVlODMwMjAyMThlZWVlYzY0Y2FjY2QxMTg3OWFjODU1ODc4OGU3NzdmOGJmNzM5MzZjMDljYmQ4MTpmYWxzZQ==
# 42000 / 554770
# 200 / 269 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NGRjNTNlNjdjYWE3YWZkNTI5YThjNjkwY2MxMDZhYTYwMjczZjgxMTcyOGMxY2YxODZhMDkxMTg4OWNlNWYzNzpmYWxzZQ==
# 269 / 269 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWUxMThkNjgwMzhiOTNkNTQ1OTA0ZWM1M2U2MjQ3YjJiNjlhZjgzOTlmOWRhMzE5Y2JjNWMxMjEzMjY1YzAzMDpmYWxzZQ==
# 42500 / 554770
# 43000 / 554770
# 107 / 107 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDExMDU4ZWZkOTNiY2QwZTc0M2E0M2Y1YjRmY2JlYWNkOWQyMmUyYzUwZjhiNWVhMzRjOGI3NjFiNTI2NDk0ODpmYWxzZQ==
# 132 / 132 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTdlYzc3MmMwMmI2MTVmZWQ4MWUxMDY0ZTBhNjU4MDkzODBkMWE0MDlmMmRiNzAwODNmMmY1NWYyM2I4MDVhYzpmYWxzZQ==
# 200 / 474 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MzQxMWY2YzU3MjZmNWJiMWU4MmMyNmY5Njg0YmRhNmIzMjcwMzQ1OWM5NTkyZGFkMjUzNDBkMTJlOGUzZjM5MDpmYWxzZQ==
# 300 / 474 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjNjNjk4NjY5ZDMxMzk3YjRmODdmNjU5OTMwZTAyZWQwNTU1ODQ4ZmNmZjRjOTg4NDc3YmM4MzFmYmZmZjBhMTpmYWxzZQ==
# 400 / 474 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWEzMjQ4YjQ3ZTVjMTBkOGZiOTczNzg3MmU0MzVmZDYwZmE5ZmUzNzc4ZThlZmViNTZlYjgwYTA1MmVjMzBjZDpmYWxzZQ==
# 474 / 474 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDZlZjY1NDJhYThmYTI2MjJjZGNmYTk3NjY4MzRjYTJiZjdiZTM0NzJlZjZhYzM1MWRjNGEwZDQ1MWVmODg2YjpmYWxzZQ==
# 43500 / 554770
# 200 / 660 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MjdiNTEzMDQ1NzRmNDY0OWMzMjQ5OTQyYTgyZmVmODc3YmQ3YzUzOTNkNDQ2ZTE0MWM5NDZkZWU3NTU1MDg4NDpmYWxzZQ==
# 300 / 660 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NGZjNTNhOWY4MDg3NThlZTNjMTg3NmY3MmUwZjc1NmUyYWYxYWM5NmJhNzQzMWQ3YTBmZjNkOWI1YjEwNjBjNjpmYWxzZQ==
# 400 / 660 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzFjMzE3ZDBhZjZjYzFjMWZiOGFhNjMxYWIyNzM0NmNhOGRmOGNhNDE4Y2M1OTNjYTE3NWMzYjNlMzNhNWUzZTpmYWxzZQ==
# 500 / 660 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTU5OTAxOTQyYWM0Nzg0MjMwNzUxZjIyMWNmNjcwNmRjNmQ2ZGM3MTBkNzEwYWQwYThmM2IzOGQxZDE5YTFmZDpmYWxzZQ==
# 600 / 660 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YmYzYTY1M2FjZGQ3OTI4MGZmOWIzMzRjMDY4ODEwMjdjMWM3NjkxMTEwZDFhNjVmZjIzNzU5YzFmNDJjNzk1ODpmYWxzZQ==
# 660 / 660 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTkwMThkM2M3NTA0ODk5N2U0NTdmYWJlZWNmMDc2NjA4MTU3ODE0MTkwY2FhMjI1MGMxZTFhYzg5MmExZDFlYzpmYWxzZQ==
# 200 / 278 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NWIyY2Q1MDA4MWVmMzNiZjMzNDZlY2YwYjZhNDEyOGFmMDVjOWZjZDM1MTI5ZjdhMjEzY2UyNzllMTFhN2RhMDpmYWxzZQ==
# 278 / 278 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YmIyZTAxYTkwMzE0ZDcxYzMxNjlhNzVkMTNhYWJjMDM0NGFlZDBmNmFjZDQ4ZjkyZjllYWEzYzcxYTAwOWZlOTpmYWxzZQ==
# 115 / 115 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDU3NGRlYWMwZDgzYWJmMjg5NjAzYTY5MzVkNjVkYWM1NTFhZTVkNzJjZjE5OWQ3YTY1MTJkOWE1NTRkYjA1NjpmYWxzZQ==
# 44000 / 554770
# 200 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MjI5Y2U1YmI2NWFlYjc3ZDFmZjE4MmZlNjNmMGM5MWIzNmQ5YTc1YWIxODk2OWEyMDQ1MDg3YmMzZDJiYTRkNDpmYWxzZQ==
# 300 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDA1MTRmMDZmZmVkNjExYTMwMTIyODMzNThkMzhjODI4MTk3MmU3YWE2OGEzYzU1MzNkNjA4ZGM3NmRlZDVlNzpmYWxzZQ==
# 400 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NWMyYjg5YmJmNmQzYzk3MWRhNWNhMDgyNTU5MjJmMDJkYmM0NzQ3ODk5NjZlZGQ0OTgwODU2MGNkNjhmZGVmZTpmYWxzZQ==
# 500 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzgzMjE3NWU2NWM3ODNiZTBmZWFjNjRiY2VjMzNhNDMzOTkxNjdjMjhhZmRjODE0OTAwZDgxZDU0YTczYzY0ZjpmYWxzZQ==
# 600 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTc3MTBjYzQ4NWVmNWQ0ODU5OGQ1MjBhNjI2ZDczNTcwNGU0NjFlOGMwZDNlZGQ3N2RmMmQ0MTg3MWM3OThhOTpmYWxzZQ==
# 700 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjRmZmIzODFiZWNkMDExYTk4ZTA2M2VmM2YzMGNhZGFhMDQ0ZWI0MWQwMmIxYjI3MGMxZTIyNGUyNmU4MzYzNTpmYWxzZQ==
# 800 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDQ5MzA2YjU2N2NmZTI4MDMwMjE3ODY4NWViYmQwMWNiZjZlN2IxYWY0NjE1OWNjMjEzMjIxODNlYzA2MmI3MzpmYWxzZQ==
# 840 / 840 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjM1YTc5ODMzY2FkOWQ1MzExNTk0Yzc5ZDNjM2Y0YTRiZDVkYjU2NjRhYzA5ZDA2NjQ3OGJjMWM2OGRlYTgxMTpmYWxzZQ==
# 200 / 258 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzUxOWY3MTAwZGFkNGVkODYzZGIzMzcwY2ZjY2ViNDgxMmI2ZDBiMjllZWU5MDk5NDdiMWJhZDM2NzgxOTVlNTpmYWxzZQ==
# 258 / 258 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Yzg3MTNlOGUxNzFhNjU4YmZhMDUxZjE0ZmNhMGQ1MzFiNWNkYTE2ODM4ZGY3ODU1ZjVhZThjN2RjMTIzNDc4YzpmYWxzZQ==
# 184 / 184 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDRiNzQ5ODFmZjFiYzlmMmVjNTRkYjRjZjY2YzU2YmVmOGUxMGY5Zjg0OGRiMjNlMTY3YTQ0ZWI5OGFkYjlhOTpmYWxzZQ==
# 44500 / 554770
# 200 / 277 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NWFiMWI5Y2UxZmQ2NGRjNzNmZTJkN2NmMWQ5NmUxODYzNmMxMDMyZjZmZTU5OWVkY2Q5ZTg4ZjM1ZWNjNmIwZjpmYWxzZQ==
# 277 / 277 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzAzZDUzYmQ3MmExMTIyMGEyYjU3YTk1YWRmNzc5MjNmMjFmYWIxYjY4MjZlNDY1ZjI2ZjUzOTVmNjZlZmZkMzpmYWxzZQ==
# 45000 / 554770
# 200 / 332 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NGY0NDkwMTYzZmQyNGI4ZTg0MjE0MWZjNzkxYmI0MGQ3OTI4NTEzOTFlMGUyZDFiZGIzM2MxYjdlN2ZjYTJhMzpmYWxzZQ==
# 300 / 332 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTljZGMyMTU0NWRhNjYxMzI1ZmQ0NmMwNjc0NTUxN2Q0M2Q1NWM5MmYzMDc1ZGExODcwNWY4Y2U4ZDY1ZmE2NjpmYWxzZQ==
# 332 / 332 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTU3MmJkMmY2ZWU2MDU5ZjE3ZjdlYjgxMzQyM2EyZWU0NzU0MzYwNGY4ZmUxZjI2OTBkZjdhZjUxNzc5NmNmNzpmYWxzZQ==
# 45500 / 554770
# 200 / 330 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDljNGFmN2E2OGJlN2NiZGM0NzViYTBkNWYzNDNkZTFjYTM0OWY3NjM2MWViYTA0ZWM4MGQzODIzNGIxZTRiMzpmYWxzZQ==
# 300 / 330 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWRhNDNlMWM0MTBlMjJiMjU5NTI1NWRlM2JmOWZiODUzNDQyYzE0NDNiNTM4YjVlODExZmZjYjg4NTYxODM2MTpmYWxzZQ==
# 330 / 330 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWFmNDBjNDA0YjFhNTE2MDg2OWZhOTdjN2IzZDkzOTcxNWIyYzY5NzA5MDJiOTBjZGVhNWJiNDUwNGMyYzdhNjpmYWxzZQ==
# 200 / 235 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTgwNGU0NzI3OGM0ZWNjZDM2NDZjM2VmYzliNTRmMTI4NGQxZTgwMzQ3ZDdiZTU0ZTM2OWQ4MWRhZWY2NGZhYTpmYWxzZQ==
# 235 / 235 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2U0ODg1MmY0Mzg4YzU0MjJmOGRmYTY2YjMxZjFmODQ5MzcyYmM5ZDY2ZjBmOTVlYTc2MzA0NGE3MjdkYTM0ZTpmYWxzZQ==
# 156 / 156 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWE2MTJhZjllZWQ3MGEwYzI5NTdhNDY2Zjc3N2MwNGU5ZGE1YjQ1YmUwYjdiN2IyNjlhMWU1OTYxODUzM2RiYjpmYWxzZQ==
# 200 / 251 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjI4MjI4YzgxNTI4YmJjY2U1ODZjOTNjZjYzOWQ4ZGNiMTIzZDIwMmVkOGEwNzA5ZTc2ZjUzNGU0Yjg4N2NmZjpmYWxzZQ==
# 251 / 251 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzJhZDVlM2QwZGM2YjliZTdmZDVlYjM0YTBlNTIwNjY3NmU5M2Y5OTE0NGY3ZjgyNGQyNGMxOTVkMzBiMzgzMjpmYWxzZQ==
# 46000 / 554770
# 131 / 131 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODhkZDVmYmI3ZDNjYmNmZGY4Y2UxYzIzMmU3YjY5Njk3NWE3NGI1OTVkZGJlOWM1MDQ2YjZjNDM2MmZkYWZjZTpmYWxzZQ==
# 181 / 181 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTM5M2UyMDY2MDdmNWI1ZDAxMjk4MTllMzJiMGNlM2RiMzM2MjIwYjkwMWUwZTE0YmE2MDZhYjMzM2FkNjQ2MzpmYWxzZQ==
# 46500 / 554770
# 200 / 350 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDNjZjkwYzZhMGU2ZTMwMWUxYzJmNzQ4MjVmOWYzYzBlNzBlY2RkNWY0ZjMzZDBjYmZkNjE3YWFkYmIwMGU2NzpmYWxzZQ==
# 300 / 350 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODc4YzA4OTEyY2Q0OGRkYjM0ZjljYzk1Njk4Mzc3NDU5ZjBmZWU4MDNiYjhiZTQ5MTYyZTY2Y2VmOGRhNTA3MTpmYWxzZQ==
# 350 / 350 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDQ3ODY0MzBjY2ExZDMyZDQwMTJiMjc0ZmQxZWVkOTkxZjcwYjQzMzdjNDUyZmVkNzMzMmM2NTI4ZTMxNDRhODpmYWxzZQ==
# 47000 / 554770
# 135 / 135 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTk2YzBjYWY5MGQ1ZGVlYWU4NmYwMDgxZWIxYjNhYmNiN2Y4YWE3YzE2ZTQ3ZWExNTY3YTQzYzY4MjVlNTlkZTpmYWxzZQ==
# 119 / 119 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGIwYjMyMDc3YzJmZTkyMWRhNmVlNmJjNTE2NWY2NWU2Y2QzYzE0NmI3YjI5NWY4ZmE3ZTI0NzE5ZTA2NWIzZDpmYWxzZQ==
# 140 / 140 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzE0OTk2NDIzOTc5MTI5MDFjMmUyYTFlZjBhMDUyZDQxNjRhYzBiNzk1ZTIzN2FiOTQxZDUyODUwYTBiMTFlMzpmYWxzZQ==
# 47500 / 554770
# 200 / 202 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzgzMWQ0MzY0NWQ5ODc0N2Q1ZjljNzQ1YWQzMmMyN2NmMzhjYTFhNjcyNGUyY2UyMmJlMjE2NWUwZDVkMTk5OTpmYWxzZQ==
# 202 / 202 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmIyYmJiYTJjNmYxYTQzY2E3MDkwNzdkNGVjODA3YzdmNDdmNDRiYjMzNmIzZWU5MWYxYTQzN2IyNGUyNmM0NzpmYWxzZQ==
# 200 / 284 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NWEwOWVjNGVlOTJlMzkyY2U2ZWExOWFjOGM5NzdmMDk2MTc2MzBlYTA1OThkOTUyOWY1ZTY5OWFhMTVlYmM2ZjpmYWxzZQ==
# 284 / 284 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YmI3ZmNmMGNiOGZjMTAyM2U2NzlkNmQwNjZjZjhmYmQ3YWVkZjY5ZDViODEzYmZhZDRjODk3OGRjZWIyY2YwNDpmYWxzZQ==
# 128 / 128 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzQ1OWMwOGM3ODQyYzM3NTM1NjEzYzVlNjMwM2JmOGY1NDY2NWFiOGQ5OGNiZTA3MzE5MGZiNTU3ZmI5M2Y2NjpmYWxzZQ==
# 48000 / 554770
# 48500 / 554770
# 197 / 197 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGE3YjZhNGU4OTAzZjkwZGFmNjg0OGNiZjFjNjUxYTQ3ZTM5MmZmMDEzZjU1MDgzZTY1NzMwNGFjYWJhOWE4MTpmYWxzZQ==
# 200 / 326 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTk1N2NkNzlhYmNlOTg5OGM1NTMwYmQxNGE5YWRkMWM2NWJjZDc2NDcyZTQ4NjRhNzgzZWMxYjQ5M2Y4MDcyMzpmYWxzZQ==
# 300 / 326 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTE0NTc4ZGY3NGVjYzI1OWEyOGZiZWNjNGNkYjk3MzVhOTY3OGI5ZmMwMzA2Mzk3OWNmYmU4YzQ1MGM3ZWUwZDpmYWxzZQ==
# 326 / 326 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWNkMTZlZjNiNmU5ZDVjNmU3MjExMzg5MjMxNDk1ODRkODkzMTc0MDZjM2UyNjcyYzI0NTU0ZTlhN2YxNTA4ZDpmYWxzZQ==
# 49000 / 554770
# 200 / 238 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzQ4ZGRhMmUxZjY5MWE1Y2FiMGJiOWVkZWZkN2FlZTkyMTY5MDU3NzY1ZTIzMjE1YmQwODA2MzFmYjdhMGE3YjpmYWxzZQ==
# 238 / 238 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDhiZDYwZjgzNTA5ZjRhYzllYmMxNTFkM2ZkN2Y0NmMyN2U2MmViNjNkOWY2ODMyY2U0NDg5M2YxYWIxZDM4ZDpmYWxzZQ==
# 118 / 118 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTYzNzU1M2E3MTAxZjFiODBjNzZiMWQ2YzQ5ZTY4NGQzYjg4MjA2NTQ1NmNiY2UxOGY3ZmIxMTNhZTZkMjFjMDpmYWxzZQ==
# 200 / 380 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDM5ODFiOTM1MzY0MDEzMGJjY2Q1YTQxMDY1OTFmYjJhNzc4ZGZjNzE0ODNmODVmMWMwYjUxZTMwZDY4ZGIyZTpmYWxzZQ==
# 300 / 380 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODQzYzMxODc3NzM4ZjIyMzcwNDNlYmUzOWVhOGVmYTY5ZGFjMGIwNDYzOGFhZjhlMWE0NmI1ZGQyNjk0NTA2YjpmYWxzZQ==
# 380 / 380 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Yzg3ZWRjZDI5ZjQ3NjNhZGYzODhmN2E0N2M2OTBhYjY5YmU3OWQ1NTEwY2E1NmRhNTVkZWFiOGE2NjFkZjE3YTpmYWxzZQ==
# 49500 / 554770
# 184 / 184 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTQ1Y2NmYTRiMzE2ZTIwMjY3MGFjY2ViMTA5YjIxZmViYjNhZWU0MTEyMzQ2YmNjZTI0MmY0MWVkN2U0NWRkZDpmYWxzZQ==
# 117 / 117 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDc1MjIzZjUxNWQwNGY0YmNhZTEzMjVjYjNlOTUyODc0MmQxODYxZmNlYjIxNTExN2M5YWZlZGRhODYxMWM3NTpmYWxzZQ==
# 200 / 243 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjFlNDJjODdiMDJhMTUwY2M4YzFkYTE3OTM3OWU0OWNiMmUzZjY3NmY5OWE4ZGIxMDY2NmRiYmVmYTA1M2EwNDpmYWxzZQ==
# 243 / 243 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDFhZGFlYjVkNjQ0ZjY1NDFhMThjNWJjM2VhNjM4ZTMwOTE2MzI1ZTE2YjA1Y2FjN2VlMmVjNTUwMDJlMzc4MTpmYWxzZQ==
# 200 / 339 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTIzNGRlYjMyNzdlZTc0ZTYwNjFiNDBlZjE4OTYxMTg5NzNjYTc3MTkwOTRiNjY5ZGI4ZmQwOWM1MjE0NjAwZTpmYWxzZQ==
# 300 / 339 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTc4MDBkOWM5ZTBhMjNiNmMyZWYxMDNiZDEwOGVkMDJkODg0YWU2OWNkOWViYTJjOWFkYjE3NTFhMTUwMTBhYjpmYWxzZQ==
# 339 / 339 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTNhZDA5ODc2MjJkNWQ4NGE5ODk0YjZiZWQ1ZjI5Y2I4YjJjNWZhZTczZWUzNmI0OWYwOTI5ZGExZTExOGY5OTpmYWxzZQ==
# 113 / 113 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTU3MjVlYmMzYWJjNGFlMmMyZjFmMTc2OTNiZGE4YmIyYzgxNGRlNjJiMzYyMzA3YjM1OGYzMTM1N2M3ZTE1MjpmYWxzZQ==
# 103 / 103 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjdlZGZmM2RjMDMxMzE1ODYyZjBiODRlZDcyMjU5ZjgwMTZkZDIwZWJiYmU3NTY3NTA0MDFkZTZmNzEyMDY1ZjpmYWxzZQ==
# 200 / 241 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjcxY2I0ZTE4ZmZmNTE3NjVjNTQ1YjAxYjRlMzE4OWE0Nzc3ODZjNGZjZmIzMjg1MTViYWI2MTA5MjcyZWU1ZTpmYWxzZQ==
# 241 / 241 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDdhZDcwM2ViYjQ3ZjUzMDUzZjAxMmZkMzQ5MDdkMDRlMmY3MmM5MjIwNGNkNmI5ZDYwZDI4YzY2MmZiYzJjNzpmYWxzZQ==
# 50000 / 554770
# 147 / 147 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTdmNDUwODRjMWY1MmRiYmFiNDMzOGQyMGVhOTk1ZjQ5MTQ0OTBjMGY2Y2U5MDg0OTg0ODRiNDRhNWM2YmQ1MTpmYWxzZQ==
# 200 / 213 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzM5ZDZkYmVmMzJmNzdiNzE5NjUxNGFiZWQ4YTY5YWViZjY0Y2RiYWU1YmZmY2E3OWFjM2M4NTIxZDQ0NmI3NDpmYWxzZQ==
# 213 / 213 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjViYjVjNTc3YTJhZDQ4MmYyZGU4MDczYTIzOGQwMDAxY2YyMDkwM2NkNGVjM2FkYjEzY2Y3NjJmNmMzZWFjZTpmYWxzZQ==
# 113 / 113 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDUxMmIzY2RmMjczZTc4NDZkNjM0Mjc4YmUyOWQzZmNkOWJhNTg0ZWY3NTRhZGJiNjYyOTQxZGFmZjM5ZjVmNTpmYWxzZQ==
# 115 / 115 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGViYzNhODNkNjA0YTQzMWMxNGNlN2JiMzRiNTQwNjg0NTliMjhhNzUzZmExMzE3YjQzZjY5YmRmM2ZjMmU2OTpmYWxzZQ==
# 50500 / 554770
# 181 / 181 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGZiM2JiNmIyNjAyMTAxY2RlMWJiNjE1MTdhMWJjNWYyMzQ1ZmNiNTdiN2FjYjU1N2YxYTIyNTZjMWNiNDNiOTpmYWxzZQ==
# 200 / 201 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmViNWI4NGZjZmU0YWIxZWQ1OGU2MzZhZjljOWVhOWE0ZWJlODI3ZjA5OTQ1NDlhYmY2MDQ0YWI3MjUzMjg2MzpmYWxzZQ==
# 201 / 201 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmQ4M2RiM2UxNjU1MjBhOGUxOTJhMTJlNjViMmY1NDAyZjYxZWRjYjFkYWU5ZDZkZTc4NWQ4M2ZlZTE0M2E4NjpmYWxzZQ==
# 200 / 257 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjNmZWRjM2UyOWMxOTc2MzJjMDExZGM4MGI1NzcwM2MzYmE0OGNkODMwODc5ZTMzNTg4MWE3ZWM0NGE0NzE1NDpmYWxzZQ==
# 257 / 257 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzNlZGY2NWRhZjhjZTFiZWNhYjkxMWViZGYxMWU1OTUzOTY0NGY5ZWMwMGMzMDhiMTQwMGU4ODlmYzU1M2FlMjpmYWxzZQ==
# 51000 / 554770
# 101 / 101 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmIxNTdiYmVjOTU5NmQ3MGE2Njc3YjU4MWJiN2IyMDljMzlkMzIyNTkwYWYzZjRiNzY0NDRkZWFkNGNjYmYyMTpmYWxzZQ==
# 117 / 117 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDQ0YzAzYzk4Y2QxNjRmNGQwOTYyYTVjZmNjMzllMzAyODliNTY5NDhiMjY3YjgwY2QyNTZlYTY0OWY3Yjg2NjpmYWxzZQ==
# 101 / 101 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmU1YmJhMjhhNzJhYmJmMTEyNGZhZjA3MzgzZjkyM2QzMjRhYzkzZTM3OGNjZDE5NTEzYjUwMzRmYWMyOTAzNzpmYWxzZQ==
# 51500 / 554770
# 200 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MTFlNWMzNmMzYWNkOGNjMGUyY2NlMDM1N2UzZTIxZjkzMjgyY2FkNjQ0MjU0NGM1NDVhMTMyMGExZmE0NmRjMzpmYWxzZQ==
# 300 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MjNiMzhlMjYxN2QwNzQ0YzIxNDExNzFjMjc3ZGZmNjM4ZmVhYjYwOWQyYTAxNTgxOGRiMGMyNDU0MjExMGQwMTpmYWxzZQ==
# 400 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MzRiNjE1Y2FlMGFiZDY4ODc0NzBmNzkwM2M1MDFlNTgzYjU3ZWE1YWI5NzhkYmFhYTQyZTZiNTYzZWVkN2Y3MzpmYWxzZQ==
# 500 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDkzYWI1ODE4ZTk5MjIxYTk1Y2NiODgyMDExNTAyYjliODg2NWVlZjM4ZGY0ZmM0NjA5NWVmODhlOTJiMmM1MzpmYWxzZQ==
# 600 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NWNmYjExZDU2ZDQxZGFlNjAyY2VhMzdiNTUzNTc2ZTE0YzdlMDQ1ZmI4OGE2OTQ4ZDA3MzQxZmJmYWMyOTIxOTpmYWxzZQ==
# 700 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmNhZDc1N2NmMzNlYjEyOWE2ZmZhZmRkOGVhOTc2MDY4NTAxNzBlNGIzZGRkMTk2NDRiZTQxMzJhMWQ2YThlMzpmYWxzZQ==
# 800 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODBlYTgwNTAyMDhhNDhlODE2ZDBiZTMzZDM0YWJmNzIxZmUyMWY2MmQzMWIyZjFkYjM3MzlmMTE1OTliOTdmNzpmYWxzZQ==
# 900 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTMyOGVlN2MzOGI1ODczZWI0MzE2YzE4OWYzODA4ZTM2Y2IxYmIxMWMwMjYyMDFjZjEwOGRmZTFlNzI4MzE2MDpmYWxzZQ==
# 1000 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTIxZGYyMDQ0MTIxYjM3ODE5MDY3M2MwYjM0M2EyYjE1N2ZkMzg3NjBkODY1YjY5MDI2ZTFiYjI2ZDRjODI2ZTpmYWxzZQ==
# 1100 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjI3N2NmNDUwYTFiZTI3ZWMxN2M4ZGU5ODkzNGQzNjdmZTVjZDU3NTllOTBmN2M3MmYwOTM0MDk4MjExYmJjYTpmYWxzZQ==
# 1200 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzQ1NjkzODg3OGVmMTdmYzVkYjFhNmU4ZDlhNzhkYTQxYzE0NjA4MjNkZjYxNDE2OWVjY2U5MTAxMTNjNTI2MDpmYWxzZQ==
# 1300 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDUwNzIxMThlNDYxNzdiMGMzZThlNjc3YTA1NjMzNmVlYTU3Nzk2YTAyMDczYzYxNzIzMDI4ZTVlOTAzMjU5NjpmYWxzZQ==
# 1400 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTkwOWMwNjdlZDJiNDlkNDI4NDI0YjAzOTcwZjMyYmQ4NTZhMTVmNTk2ZjJmYzgxMzhiM2MxMmI5MGNhOWZmYTpmYWxzZQ==
# 1431 / 1431 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmFhYzY4NGZiNWYzYjY2MDg3YjJmYWI4MzgwMzQ3NWJmNzUxZjVjN2U3OGQzODU0YTkwM2RhMGY3YzAyN2NhODpmYWxzZQ==
# 167 / 167 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWJiZGNmZTRkNmQ2NjQwNGNlYWY5ZDdjMDViYjBkZmVlN2Q1YzAxNjIyZGVhNWM0ODgwN2FmZjQzNTNiNjk0ZDpmYWxzZQ==
# 52000 / 554770
# 190 / 190 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTA4MTE2MTJjMmE5NmMwNmY1ZWI2OGFhMzg0MTU5ZGJjYmEwYTdhZWI4NTg5Yjc3YWY2ZGJlNGIzMGMzMjUzZDpmYWxzZQ==
# 200 / 576 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MmU1OTllODI5OTY5Nzg2ZWJhN2FiZmUxYWUyZGU0MDE4NmY2ODgyMzk2MDQ2ZDU4ZDk3ZmUwNzEzZTgxMzIzOTpmYWxzZQ==
# 300 / 576 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjExMWViOGU2YzA5NmFkMTQ3ZDMyNzc0ZGQxZDJmNThmZDhjMDQyNWYzYTQyYzZkY2RlNGJjOWU5NjU2N2U0YzpmYWxzZQ==
# 400 / 576 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGZlMGZkYWQ4ZTVlNDE0NmI5ZTg0YzY2Mjg0NmQxYzk1Y2QwNDY3MDQ4NzI1NzdiNGM4MzNjMTJhYWYzNmVhMzpmYWxzZQ==
# 500 / 576 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YmQwZGJkYWI0OTY2OGViMDYyZmIwZDg1YjYxODBlNGZjZjlhYjVmMWMwNjU3YWY3MWUyMzU5YmY2NzI2ZGUxODpmYWxzZQ==
# 576 / 576 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTJjYjM3N2YzMzg2YjIxNWFiMDk2NjU5YmMyZmNjYzU0NWMyODRhODJkYTZiN2QzNmQxMWI5OTUwYjE2OGE4OTpmYWxzZQ==
# 200 / 382 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDY1MjI4M2U1MjUwOTYzZjAyMWIzYjRlMjUwMTA1OWFjNTE4ZjljZGQyNmIyNDk0ZTk5YjQ5OTNhYTQ0NjE0YjpmYWxzZQ==
# 300 / 382 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODcyMGE5MDhkZGYxZWM4OTA3MWRiMGE1NTY2MDIxMWM2ODk0MjM0N2E3YTg0MjFmZjZlNjZkZmYxZmE2MDQxYjpmYWxzZQ==
# 382 / 382 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2M1M2ZhZjkwMTE0MjE0YTlmMzhhZDg3MjZhYTFkZTA3ZWRkZWVlMDZiZTZkNzEzZDA3NzRiMGI4YTE4NDRmMDpmYWxzZQ==
# 200 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MTVkMTJiZTI5NWQ0MDk4MGQxMTQyZjBjMGEzMDJiYjMwNDFiMmU5MWFmMjgzMjMyYzFiNDBlNGU1OWRjMDc0ZTpmYWxzZQ==
# 300 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MzE4YTI2ODNlMWE0ZjNhN2YzYjcyYTUzMGQwOTQzOGZhOWIxZjM3MzQ4N2I2MzAzOTMzNjMzZjQ1ZDgzNmY4OTpmYWxzZQ==
# 400 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NGRkNTFlOTdmOWZiNDczZTUyNGU3ZDA2YTkyMDliMzExYTE0MzhkZjUwZjM3ZjAxNWY3YThjZjBmMDhhZGVlNjpmYWxzZQ==
# 500 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmQ5MDA2MGE0ZjkyMjgyYjY2MmJkMTAwZTE0YTdmMjhiOGI5OTJlOGE4OWY4NmU5OWZkMjE3MmE4ZmJkOWExYzpmYWxzZQ==
# 600 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODcyZDk1ZjJmMzdlMmM1NjQ5N2Y4MWM2OGMwOTc0ZjU2ZGQ5YjgzMTA4NWNhMTFiY2NhYThlNWYzM2E1ZTVmMTpmYWxzZQ==
# 700 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTFkYzU0Yjg4MWU0MmZjMWMzNTcxNGI0ZWIwMTk1ZDAzZGYyNTNlNDU5Y2IwZDRkNmIxOTg1M2I1ZDYxNzM2NTpmYWxzZQ==
# 800 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YmI4ZWY1NWFlYWJiYWE5MmVlYTU4MjNlN2YzNzE2NTcxZjI0YmRiYjViM2Y1MGYzM2YwODQ5ZGFjZjNhZjZhMjpmYWxzZQ==
# 900 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDg1ZmQ5ZTQ5NTNiYTVkZmQxZDIyZWU2MGEwYjU5NjgyM2ExNjk1YTJiMzFlMGQ2YmMyMGQyNDU0ZmJiZWUxNjpmYWxzZQ==
# 939 / 939 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjU1Yzk1Yzg5YzVjZmMwYmQ2MjYyYjMyZDQzOTA3MzYwNWNhM2ZjM2I2OTczZjc4NWUzYjFjMTQ3NGRlY2JkMDpmYWxzZQ==
# 166 / 166 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWEwNGUyN2NlMmVhNThhMDQ1MDBhZjhjMjE2MjcxYjE5ZGU4NGFiZDM3ZTUyYTNlMzJmODg5MTVhYjUzMTZjODpmYWxzZQ==
# 200 / 429 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4M2RiNDFlMjJlMjZhOGM2YzZlMmM2ODJhMzY0ODdmMmNhNzVmMjA2YzQ0OGMzNzE0N2FjOGRiYjI1ODZlYzQ0NTpmYWxzZQ==
# 300 / 429 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzU3MzQ5Y2IwYmRmMWZhYTNlMDMyNDRiNjdjM2Q1ZGQ5MTNhZmY3NzQxNTEyYTJiMjRmZjc5N2UwZWUxOWE3YzpmYWxzZQ==
# 400 / 429 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjQ0YzcyNmJjNDQyODEzNjBkZTI2MDNhOTM3OGY1ZWRmNDU0ZTdlMWYzNTdmMTQzMjhhNTFmOWExZTA2ODUxZjpmYWxzZQ==
# 429 / 429 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWZlNTI0Mjk0YzRlYmJjZDY5ODY5ZGUxMzU1ZjNmZTAyMWE2ZjZjZTg4OGFiODY4MjNkYWUwMTNiYTcxMmI4ODpmYWxzZQ==
# 52500 / 554770
# 200 / 380 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4M2Y0YjIxMWE4NzgwMmEyYzU4MDJiZDI0OWYwMzA3ZWI1NGFiOGY1OGI4N2YwNWJiZDI4Mzg5NDc1MDEwNWIwMTpmYWxzZQ==
# 300 / 380 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODg0YWRjN2Y3ZmUyNmNlYzg2MDczYzUxZThmZmJlMmI3ZjA3NGVlZWJhNWMwMDM4ZmQ5Y2EwNmI1YzIyMzZjYTpmYWxzZQ==
# 380 / 380 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDNmZmVjMTk4MWZiZDQyZWE0YWJiMWMyMTIyZWU4OTljY2VlZjdmNDNiODY3MDFhOWU0MGI5ODU4ZDhhNTdjODpmYWxzZQ==
# 200 / 267 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjY4MWRkZTk0MWQzZjE3MjRhZjgwM2YwOTYzYThkZjYzODY3ZmM4MmRmNzk1OWJhOTVhMTBhOGY3YTMxYjY3YjpmYWxzZQ==
# 267 / 267 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzAxZTFmMmZjNjk5NmEyNDRiNzlmYTk1ZTJmZjIwYTczOWY4YjhkODAwMWVmNmRiZjQyNTFkZjkyYTNkZDkxNzpmYWxzZQ==
# 53000 / 554770
# 115 / 115 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGJjN2MyOTI1ZmQxNGU3ZDAyZmExZDczNjM3ZjUyYWMxNDg1MDJiY2NmN2Q3MDVhZWEwMzllYjY0NjQ0YTMyZTpmYWxzZQ==
# 200 / 403 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MzViMjVlMTE4MzNjMjExMzYxYzQ0NTk2YWM1MGM1ZjNiMDFlNjg5MjBlMmI4YWIwOTU4NzhhZTg1NTNiZTMyODpmYWxzZQ==
# 300 / 403 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzEyNTgzMjU2ZTA0YjM5MmI2YWNkNDdhYzY3OWUwZGNiNDg3YzA1YmJlZjU2ZDFkNzdmODViZDNmNmZjN2EzNDpmYWxzZQ==
# 400 / 403 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjJiMzI0ZjllZGE5MDNkZWRmNjY2MDE1NDZhNWJlN2NhOTQ4ZTQxMWFhNmFlMmM0NDM3Yzc1NGEwZjlhYzY2NzpmYWxzZQ==
# 403 / 403 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmVhMjA4NDA5Zjc0ZjM1MjkyNjJjNDE3NmFlMGRhZDNhYjUxZGNkNDZlN2ZlMzIxYjg5ZWIyNzNjZDFmMmFiNDpmYWxzZQ==
# 200 / 311 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTJiOTkxZDU0MWZmNDBjMGI1YzE0NmI1Zjg5YTg5MjMyZjdkODVmMTc3MzI0M2EyZjVjZjBkMWIzN2FlYmY1ZDpmYWxzZQ==
# 300 / 311 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWY3MjMxZjZkZTFhMDI3MDM5YjEwMzQ2YzBkYTkxNWYyNDJmOTc1N2NkZmY2ZjA1OTY5NzcwYTRkNWI4MWYwZTpmYWxzZQ==
# 311 / 311 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjNhNzY2NzFkNGRiMWRhMzFjOWE5YjVhODhiMTY3NWFjZTFlNDc3YzNhODE5M2ZlMmEzODQ1ZWRlNjY5YTExOTpmYWxzZQ==
# 53500 / 554770
# 200 / 240 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmUzYjhlM2U2NTNiYTQ2MDM5ODE4MTY2NGFkNGYzZWUxNzZjNjM5Y2YzZjkzMTM4OTc2MTI5NTI2YzY5MjIxMjpmYWxzZQ==
# 240 / 240 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDgxYjVlZDdlZmE1Mzk0MGU0YmI0M2I4OWIzMTI5OGQxNTY1YzczNzM4NDYxODVlODRlMzk4ZTE2MTRkNzE4ZTpmYWxzZQ==
# 54000 / 554770
# 157 / 157 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTM3NGMwOTMzZGRlZWU3MDNmYTE2NDY3YzFhNmUwNTM2Zjg0MzdhOWRlY2YwMjA1N2ZlNmRlYzdlMWYyOTA3NzpmYWxzZQ==
# 181 / 181 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTU1MjdjMjAwZDIyMTcxNGFjZWEyYzMxZTA5ZmM3OGJkNjJkZTRhOTAzMDFiMmEzNWU1MDRmMzVjYzQyOGYxYzpmYWxzZQ==
# 106 / 106 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWE2ODQ4ZGZiMGY0MzFkNDUwZWE0ODQ5ZTRlMzhlNzZkODY3Y2MxMzNmNjE0YTMwNzZjZWJiMWFmMDE2OTg1NzpmYWxzZQ==
# 115 / 115 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGZiMDQ3YTBlNTc2YmVkNzk0MjczN2RhOTVjY2Q2ZDc1N2M5MzFmM2Y5M2M4YWEzNjE4MjE0MTAyMTc4NzNiMjpmYWxzZQ==
# 54500 / 554770
# 191 / 191 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGMwODA4OWJmZGU5ZDQ1MTlkMGM1YTYzZmI2NjM5NjU3NTE0NTkyZjZmMjQxNTkxYWIwMzc1NDUyYTc2M2Q3NTpmYWxzZQ==
# 200 / 243 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmY5NjdkNWY2OThhM2NkZjlkOTQ5NzE2NmFlMzhlNmU1MTZiM2YxYmQyMWNjYmM5M2ZhNzU3NjFmNWI2ZmRhNDpmYWxzZQ==
# 243 / 243 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2Q4NDQzZjVjZTc4NWVhYzgzOTIyNTExYWNhMzA3ZWE0ZDRhN2U1YWFhYjI5ZWVkNWUzMWEzYTQyMDc1YmVlODpmYWxzZQ==
# 155 / 155 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWEzYjYwMzk0NGJiNTk4NWNjNDlmOTIzOGUwZTU2ZjgzYzNmNjQ5NWIyNjg4NzBmZjI4YmE1YWM0YzY3ZDM5MTpmYWxzZQ==
# 55000 / 554770
# 181 / 181 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTMxMjM4NDZlNmE1OTVkOWM3NWIxNzk2ZjFhYjEyNGUyMjM3OTVhMGJmOTYyZGY1ZjJjNWZkZTE5ZmQyMWMwNjpmYWxzZQ==
# 55500 / 554770
# 193 / 193 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjVhODg4NWRhZWIzNTg2YmY2MmQyMmNlMzY5NDNmZDZiOTE5OWJkNGJhMDlhMWQxOTUwYjcwMDhiNWM4YTBhOTpmYWxzZQ==
# 162 / 162 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTY1Nzk4NTJmOWMzNTQ1ZTY4NWVmNTE2M2NlYjM1ZjhmYTc0ZWRhMWQ4NTI5MmI4NTZmMGY1MTVkMGEzNDkyMDpmYWxzZQ==
# 200 / 548 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MmFlZDNjYzBhMzU2ZDExZjRlODNhNjE1YzRlZWFiZmQ5Y2JmNWRmNDdmMGU0Zjc4ZmUwZWVmYTJkYzgzYjZkYzpmYWxzZQ==
# 300 / 548 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NWU0NGRmMTIwZGE0MWU2MTE2YjM5MTYzMWM4NjcwMTU5YjI3ZjExZTM2NTA1ZGFkZDM3ZTE1Y2E4ZjI2ZDM3ZTpmYWxzZQ==
# 400 / 548 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGYyMzc3Y2I2OTU5YWQ3NWY3MmZmYzM5ZWZkZTJhYTFhNTg2YWNjYjQyMDAwYjBhZGRkZDY3ODBkNGQ3NDU4ZDpmYWxzZQ==
# 500 / 548 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzE2YTc3NTk2YzZjYmUxYzdlNmU3NzhmMDVhZjlmZjFhYmRlNTgzMWY3MWRiZTQwNWYxZjg2N2Q5NWI0NjQzZjpmYWxzZQ==
# 548 / 548 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWVhMjAwODFkZGMwMDVlY2IyZGRkOGZhODIzNTdkZWRkYTgyYjQwMDc1YzY0MTJkODFiZWYxNzE2YWYwNjYzMzpmYWxzZQ==
# 181 / 181 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODkyMDNjZWJmMmRjZGRhN2Q2NjU3NmE1MWRkZTQyYTE2ZjJjOWVlZWQ3OGFlYmYyODU3MzA1NDdhNDNiYjNkZDpmYWxzZQ==
# 200 / 329 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTlmOGZlMzJjMTc3NjNkMzY3NGI4NmEyM2RiN2ZmOWFlNTI3OTk3MjI1YmJkMTkzY2FmZTAxZDFiZDExNzViOTpmYWxzZQ==
# 300 / 329 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWNiZWFkMTE2YThiOTljMDcyNTI0YzBjODA0NzBmNzdlNTJkYzVmYjE4YzgyYmQ0YWI5MjQ1M2U2NjU3ZWUwOTpmYWxzZQ==
# 329 / 329 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWU0OGIwMTUxZTdkY2IyZmQ0ZjE1Mzc0MjA5NDMxZjFjZjg3ZDBmOWRmNWZjYTY2NjEwYzU3YzFiZWYxZjdiYzpmYWxzZQ==
# 110 / 110 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWNkNWY1MTNmZGUzMDEzNTZiZTkzYzJmMzc1ZmRmYjdlNmE2ZjgwMWNiMTYxMTI5Y2RiNzMxYjMwMzU5MjY3MzpmYWxzZQ==
# 200 / 348 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTA0ZjdjYTRlODdhZmViM2I0YTlkN2M5MDg0MDBiODllZTUzMGZjNzlhYTkyYTcwYTBlMzA3MzA5ODVhNmNkZTpmYWxzZQ==
# 300 / 348 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTdmZDY4YzdjNDM5ZGMxMTU0YjUwODI5YTAwMTU4ZGE0NmI4ZTZlMTRiMTJkNzU4YWRkN2E2MjYzNDJmZDY0NjpmYWxzZQ==
# 348 / 348 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTY1OGU1NzNmYjVmODBiY2IyMGEzZmE5M2ZhZTkyMzdlZDAyODY1ZTRiOTY3YWY3ZTIzMmRkNTRjNTFhZDcwYTpmYWxzZQ==
# 56000 / 554770
# 163 / 163 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTZiOTUwOTI1OTU2MjE4N2I4NzVkMjAyYWFlNTEzMjkzYTRiMTIzM2YwOWRjNzZlMjZlYjEyYzEwNzJhNDA0MDpmYWxzZQ==
# 200 / 258 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTZiNjQ3ZmNmODk5ZTY1ZDQxYTA3ZjAxYWEyOWFjMzBiNWQ5ZGU4MTZjZjdiM2FkZTY3MDFjOGZjYzMxNDUzODpmYWxzZQ==
# 258 / 258 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzdjZWVlYjdlZmEyNzZkODlhYTJjZjk1ZDlmZmViZjE2MzdjN2ZhNGFhZWMyMjg2ZjUzNDQwNDhjZTVhMTg4MTpmYWxzZQ==
# 56500 / 554770
# 200 / 299 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTQ2ZWY5NGIyYjMyYTJhNGY3NzYwNzM1Y2E4YzcwZjZiMDg1ZTg0YjQxMjcyMTA4NmE3ZjU4NWM0MjMwNjc4ZDpmYWxzZQ==
# 299 / 299 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWIzMTRkNGJlYjE3ZDM0YjUxNmVlNzdjYTMwZDliN2QyNzA2ZTIxMmM0ZGUyNmEyZTM5MDEyYzI5MGUyNDQ4YjpmYWxzZQ==
# 112 / 112 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjA0NWMxYmQ3ZmI0ZWU2OTVkZWVmNjc5MTZiZGEwYWExMmM2YzE2MWI2OGM2NzQ5OGZmYmZjNWRmM2U2MWUzOTpmYWxzZQ==
# 199 / 199 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzU4ZGM4YjcwMTFiYzgyYWU1MDhhYjlmY2QzNTQzNDllMmM5ZGViMGE3ZDEyNTFhMDE2YWE4MTQzNDQ0MDI2NjpmYWxzZQ==
# 57000 / 554770
# 162 / 162 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTI5ZTk1OGVhNGQzMTM2YTc0NDM3YjdkODk4OGZlNmE3ZjQ2MTA1ZDk3ZmVhN2Q3ZWZjMzk1MmVlNzBhMjdmNzpmYWxzZQ==
# 109 / 109 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzZhZGU4NDkzMzMzMzM2NWU2YmM1Nzg4ZDZmYWQ4MmFlNjU0ZmMzNzU3NDU4MzQzY2NhMTM3YTM1YWQzZTFmZjpmYWxzZQ==
# 200 / 217 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzdkMjllOWQ3OTQwYzQ0ZTM3OWU3YWY0MDVjNDJhNWU1YmI2MWMzYjk5MjE0NWUxZTI3MmMxYWMzOTU1YzljNjpmYWxzZQ==
# 217 / 217 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWQzZDA1NzIyNDhmOGZiZjk2MDU0YTcwNTNjYmU2ZjM4OGI1Yjk3OTdlZTJmNjFmNWQ2NDY0NzVlNzQ5NDc0YzpmYWxzZQ==
# 57500 / 554770
# 111 / 111 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTAxYjMzN2NmYzgwOTE2NDVhMGJjOTVhMjVlMDhlZTM2MWViNTdiNjQ2N2Y0MWVjZTdlODdlMjEzMmEwNWYzMjpmYWxzZQ==
# 200 / 370 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4M2ZiNTMxNWQ5MTE0NzBiNjY4N2YxZWVlMjMwMWIxZjExNjZhNmVlNTZkNThjYjFmOWYzNTBiMTEwNzFmYjdlYzpmYWxzZQ==
# 300 / 370 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4N2JkNjlmNDI5YzdiMDE4NDNmNDlhM2M0YjhiYjE1MmZjOTMxOTVmYzJiNzVkOTBjN2ZlZDU3MDdmMDU1NGJjMTpmYWxzZQ==
# 370 / 370 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzRhZjdjMjZlZjUwMTU5ODUyNWU1MGU5MTc5MDdhYzYxMTYyM2U3NjY0OGMyNjM5NzQ0ODdjYWU5NTA3Y2FmMjpmYWxzZQ==
# 138 / 138 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjJmZjUwN2JjYjMwNDg3NGVkYjgxYjcxNTQ5Y2Q0Y2JjNGJmYjQyNTMyOTY4ODk4Zjk0YzRmMjU4ZTNiMDUyMjpmYWxzZQ==
# 58000 / 554770
# 58500 / 554770
# 112 / 112 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTc3Y2Q1OGZkYjMyN2YwNmY4ZTBmMTExODcxYTQzNGE1YjgwNDNiOWQ4YmIyMjZkNmQxZWE4YmI1ZDNkZTRlZDpmYWxzZQ==
# 59000 / 554770
# 102 / 102 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjljYzEyNzgzMTg2MDlmZjNlZjgwNGQzNzIwODdkOTFhNmUxZDQ4MGMyMTdmMDllYWNjNDgyNmY3MjE3YTYxODpmYWxzZQ==
# 195 / 195 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGFiNjRhMjJiODg0NGIzOWNhYjBjMzk1ZmY2NzQ2YWM1MGVhMGY4NGFhMTFjOGEzNDI4N2M0NTc2ZWQyNGI1NDpmYWxzZQ==
# 59500 / 554770
# 200 / 235 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjhlY2E2ZjYyOGFmMGFlZDNjZWNhMGU5OTJkMmRjYWFkMmU2N2RiNjdmNmI4MmE5NjYxYTY3NjExZDEyNzFmNzpmYWxzZQ==
# 235 / 235 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGE5OGQ3NTdkNGU5OGE2MTNjNmQ4YWIwOTVlNjc4NzlhNzUyZmM0N2NjZmI3NDk2YjJkZGRlYjA5OTEyYjliMDpmYWxzZQ==
# 164 / 164 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTA4ZWVmMmRkNWNjNjJhZGEzMjJkOWY1NWE5NDkzYjgwYTdmNTkyOGUyMDRmMmRmY2NhYjA5NmIwMGE1ZTgyZDpmYWxzZQ==
# 200 / 612 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MmEwZmVlMjIyM2QwMGU3MWRkZDYwOGE4ZTU2MzkzZDU0ODk4Y2NmOTk4Mjc4OTViNzk5NjA1NGM4YTgzYjEyYzpmYWxzZQ==
# 300 / 612 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTUwNjA1MDRiZjQ3MmMyYTQwN2U5MTQ2YzdlMGFlNTI4MWQyMDUzOTdkMzc0Yjk5YzNiNTk1MjFmMzQ4ZWZkMzpmYWxzZQ==
# 400 / 612 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODBkOWY1NTM3OTRmZDBkZWIzNmMyYzU4NDA0ZjU0MTQ2OTkwZDAzMzc3YzM5YjMyNzgwYzljZmE3ZGYzZjI3MzpmYWxzZQ==
# 500 / 612 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWE4MzBkZDk0NzBiZjU5MWE3MjQxNDRlNDkwYWM5OTFhNmRlNDkzNGE1ZGNjMWZiZDhkMTM0ZmNkYjQyMGVlNzpmYWxzZQ==
# 600 / 612 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2MzZjJhNmJmZGI1M2QxMzMwMjE5NjNiYjYyZDNlOTdkNjI3YTNlYTliNWI3ZDQxM2JiN2Q1NWYwYzNkNjRkOTpmYWxzZQ==
# 612 / 612 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZmI2YzQzMjBiYzgzZTA2NjVlOGU4ZDdjOGZkNzZlNjFiNzY4YmJhNjBjZGI2MDNkNmUyYjJjOWE5MDRkZTcyMjpmYWxzZQ==
# 60000 / 554770
# 189 / 189 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ODZmYWVjODAxMjYxODRiMjQ5NzZiYWY1MmY4YTM0Nzc3Y2RiZDFmNmZhNDM1ZWI4YTZmOGFiMjgzY2IyM2RlMzpmYWxzZQ==
# 118 / 118 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTc4NGE5Yjk0YWZiZDM0OGExYWIzYmY2NGJkNzYxZGMxZjY5M2FhNWNlNGMwNzIwYzFiZDQ4MjQ0YjMxOTM5ZDpmYWxzZQ==
# 200 / 322 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDY5OWIwOTU5MWU2N2MxZGRkYmYwODFmZWM4MzJmMGJiMWVkZmU0MTNhZTE1Yjg3NDViYWVlOTNjZGZkOTBmODpmYWxzZQ==
# 300 / 322 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OWJkOWQzMjZmYWMwNjAzMjA2ZmVmZDRmNTg4ZjY5ODAwYmMxYWM1MTFjNmNmYTEyZDBmNTE2MWM4MmM3OWU5MjpmYWxzZQ==
# 322 / 322 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZWFkZmRmM2M0NzE2M2NlNTgwMjM4ZDA5Y2QyMWQ0YTE1ZDk5NjgxNThkYzY3ODcwNmIyYTkwNTA3ZmEwYmM5NTpmYWxzZQ==
# 200 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MTZkZTk2NWUxMWY5ZmZhZTg0YzViY2ZjMjgwNTVhNjMzOTViYTg4MGY1NzIzODRkMWViNGQ1ODdmYTA5OGU3MzpmYWxzZQ==
# 300 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MmQ2ZTViMGViYmJkYjhlY2VlYjkzNjQzZWJhYjJkYWEwNDRjNDJkNjdlOTNlMDBjNmE2MTUxM2UwZjIxMGZlODpmYWxzZQ==
# 400 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDgxZmY0MTEzNWM0ODZhZjczM2QzOGUxMGZhOGIyNzA3YmNhNWFhNjNiNDk4NGNlYTMwMTk0YjRhMDAwMjFmMTpmYWxzZQ==
# 500 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjFiYmQ0ZDVlMmIxNzNlMDRhMmE5ZjJmNTViZTVlZGQ2NTJiZDcyMTQxMzJjYWU0MDBhMTYyMDNhNmI0ZWFhZjpmYWxzZQ==
# 600 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzhjYzZmNzgwMWUzNjIxNTdkZWIyYzFkYjRhYjA5MzBiNWM3YTMyN2ZhMWViZjE4ZjI4NThjMmQxOGQ0MWMyYzpmYWxzZQ==
# 700 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OTFkNjk5NjAyYjRkZGRkN2ZiNjRkZTUzY2Q5OGRkYjM0M2Y0Y2I5MmFhOGZjYmQ1NGRlZmUwYjk2MjE1MWFkZDpmYWxzZQ==
# 800 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YWJhYzFkYWQwZmMzN2Q1NGM4ZDljZDRhNmM2NzBhNzIwZjhlMGM5MGZkN2Q0NWMxOTRlYzg1ODYwOGVjMjIwOTpmYWxzZQ==
# 900 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzJlZDVmODc3MGM4NjIxMjYzNDY0ZDA0NGUzYjc1N2IyYTZjNDQzYjIxNzYyMzc5ZmUyM2U0NzYxYmJlYzQ4ZTpmYWxzZQ==
# 1000 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGJiMDQyNWEwYjllYzVhODU1NWZmZWZlMjRhNDUzOTM1ZDI4MzBkZjEyNWZhNDhkMjdjYTJmMmExMWZjYTUwMjpmYWxzZQ==
# 1048 / 1048 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjQxNWU3ZjZkYzAxOTAwZDU5MDlhM2Y3ZDMzYmRmODc2NTVlZDcyMzhmMGU4YmFmN2JmMTc1M2VjNzMwMTY1ODpmYWxzZQ==
# 200 / 296 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NTdhM2E5ZThkMzBlNjljYTM2NTA3YmFhNDI3M2MzNjUzODUzOTlhMmU5MThmNDdkZTc1OGVkZmYwMTc5NmEzOTpmYWxzZQ==
# 60500 / 554770
# 200 / 235 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NjQ2OGJmNzY5ZDVlMWI1MjZiMGQzZWVkMDYzYjBlMzhkZmQ2NzI4ZmY4YmU3ZjQzZjYwMDAxY2Q1MjljZGE0ZDpmYWxzZQ==
# 235 / 235 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2NmZmI2YjA2NjAzYmZkMDZlYjc3NTkwOWE5MzQ0ZjYxMzQ1ZWRiYjFhNjNiMDY1OWYxMWExYjc3YTRjZDU1YzpmYWxzZQ==
# 200 / 362 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NGMzYThhNDhkMWUxY2I2MTU3OGYyODk0ZWMwZDllNWYyNzdhNjdhNGJmMDAxODMxMzg5ZDQxNWVkZmYzYmM4ODpmYWxzZQ==
# 300 / 362 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OGE2Yzg0NGY3OWQ1ZTU1ZmQ5YTIwOTU2NTVmZWE5MDZkNGM5YzJjNzI1YmI1OGFiZTQwMjY4MDI5OWFiZTkyNDpmYWxzZQ==
# 362 / 362 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZDQ1ZWIxMzAxOTllYzhlNzg1OGU2ZDI5MTQwMDcwYzcxNmE4MWI3OWI5NDdkODUwNTM5MjJkNjRkOGRhZjIzNzpmYWxzZQ==
# 61000 / 554770
# 125 / 125 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4Y2Q0YjJlNGE3ODllYjU5NzZiY2EzZjNlNWY4OGFkMzFjNWRiZGMyNjcxZDgzOWFlNWFlZGM0MjE0NTk2YWQxMjpmYWxzZQ==
# 61500 / 554770
# 200 / 339 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDViMTJhNmIwNTlhZWU5ZGU2OTE2Y2FmNjFkNjdlMDJiYWMzMWJkNWM5NDc3OTU4NmJhMWJiYzU3ODJkZWFiNDpmYWxzZQ==
# 300 / 339 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4OThlNDIxZGVkZDUzYzA5MTIzNTBlODAzMDY5YTE4ZGM0YWMyMDg4ZmMyNzk0YmYyODA3YzlhZTY5MzBiY2E3MjpmYWxzZQ==
# 339 / 339 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZGVhYzBjZTUyMmZhYmJkYjE1YjY0ZWM1MDlmYWU4MmJhNmE3MTYzN2FlODRiMzdjZTNlMzI0MmIwYTIyZWZhNjpmYWxzZQ==
# 172 / 172 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTM1Y2Y0ZWE3MjFjMDAyOGM5ZDhkOTA5ZDNjNTMzOWIzMzg5YWYxNDQxNDBhNmU2ZWRlNGQyOTdkMGQ1MzA1MDpmYWxzZQ==
# 200 / 446 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NDA0YzhkYWYzNDJhZjA5NTQ4Njc0YzFmMjRjMDU5MDBiZmU1YTI0MjIxYzIzMjJiMzFjODFkMTJmOWYwMTBiMjpmYWxzZQ==
# 300 / 446 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzM0NGM5NGQ5YmMzYjQyMmE4MzhmM2Q5ODQ2ZTE5ZGU3NjNkNzE2NDM2NGZkYjZiYzA3ZDU5MzljODllYjlkNTpmYWxzZQ==
# 400 / 446 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YTkzY2I4ZTUzMzRhN2QyZjkzZjRlYzE0YWVkNTc0NTFlZjBlZjdhZmNmNTQzYWIwN2U1ODJkZmIwNzA0ODRiODpmYWxzZQ==
# 446 / 446 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZTM1NThiYTFhM2Y0ZWE3NWRmMjdjNzE4MDM0NzYyZjFkODVjYTQ1NTgwZjQ0YWI0MDUzMzRjZjMzN2E3MmM1OTpmYWxzZQ==
# 200 / 422 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4MzUzNzQ3OTFlMmZiNjBlN2UxNmI2ZTkzODFmZTkwNDFmMzFkY2Q2M2Y2ZjQyMWQ3ZjBhNTAwMTU4YWFkYjVmMDpmYWxzZQ==
# 300 / 422 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NzczMTIyNmRhYTM4MzZkZTg3OWNhMWQ0YjVjNTIyZjc5ODE0MDk1MjczYmE3NWQyYzM2ZGJmZjhlOWFkYjBmYzpmYWxzZQ==
# 400 / 422 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YjU1NjBjMmY1ZDI1N2ZiMGUxMGYwMmRmYWMwMTZmNThiNDZhNjQ4MjdkYzc0NGE1MjczZGRjODZmOGJkNmM4ZDpmYWxzZQ==
# 422 / 422 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4ZjNmZjIyYzFmZTgyODQyODMyMWEyM2U3MTkyYzQ3NWEwN2VlOTBkZDE3NzYwYTZhYTRhYjc5MGFjNGRmZmU2NDpmYWxzZQ==
# 200 / 253 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4NmFiZmI1N2EzNDU2MDA4OTFjMjVhMjY5YjNlMDcwMDA2NTcwOWE3MTQ1ZjdhYmQwNzYxZTdiZTJkZjM4ZmFjZjpmYWxzZQ==
# 253 / 253 MHg1N2YxODg3YThiZjE5YjE0ZmMwZGY2ZmQ5YjJhY2M5YWYxNDdlYTg1OjB4YzY2OGQxYjk1ZjE2YTJhYTcwZTE5MzdmMjViYjRhNzAyMGU4OWM4OTNmMjY2NWIyZmMwNzZmOWNiZWQxMTg5MjpmYWxzZQ==
# 62000 / 554770
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-eebe37352eb9> in <module>
#      19     df=df.append(nft_df)
#      20     i+=1
# ---> 21     df=df.drop_duplicates()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5106
#    5107         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5108         duplicated = self.duplicated(subset, keep=keep)
#    5109
#    5110         result = self[-duplicated]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    5245
#    5246         vals = (col.values for name, col in self.items() if name in subset)
# -> 5247         labels, shape = map(list, zip(*map(f, vals)))
#    5248
#    5249         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in f(vals)
#    5219
#    5220         def f(vals):
# -> 5221             labels, shape = algorithms.factorize(
#    5222                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT)
#    5223             )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     675             na_value = None
#     676
# --> 677         codes, uniques = _factorize_array(
#     678             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     679         )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     498
#     499     table = hash_klass(size_hint or len(values))
# --> 500     uniques, codes = table.factorize(
#     501         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     502     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable._unique()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      12 ]
#      13
# ---> 14 @set_module('numpy')
#      15 def asarray(a, dtype=None, order=None):
#      16     """Convert the input to an array.
#
# KeyboardInterrupt:

# %%
# i

# %% [markdown]
# # get nft sales

# %%
# start about y ear ago, assuming about 6k blocks/day
startBlock = w3.eth.block_number - 6000 * 365 * 4 # should get all trades since ens was created may 2019 on opensea
print(f'startBlock = {startBlock}')
startLogIndex=0

latestBlock = w3.eth.block_number
print(f'latestBlock = {latestBlock}')

url = base_url + f"/getNFTSales?startBlock={startBlock}&startLogIndex={startLogIndex}&startBundleIndex=0&ascendingOrder=true&marketplace=seaport&contractAddress={ens_nft_address}&buyerIsMaker=true"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)

returned_sales_df = pd.DataFrame(response.json()['nftSales'])
nft_sales_df = returned_sales_df

newBlockNumber = response.json()['nftSales'][-1]['blockNumber']
newLogIndex = response.json()['nftSales'][-1]['logIndex']

lastPrintBlock = newBlockNumber

while newBlockNumber < latestBlock and len(returned_sales_df)>1:
    
    if newBlockNumber - lastPrintBlock > 6000*7: # print feedback for about each week worth of blocks
        lastPrintBlock = newBlockNumber
        print(f'block {newBlockNumber} / {latestBlock} ({(newBlockNumber-startBlock) / (latestBlock-startBlock) * 100}% done)')
    
    url = base_url + f"/getNFTSales?startBlock={newBlockNumber}&startLogIndex={newLogIndex}&startBundleIndex=0&ascendingOrder=true&marketplace=seaport&contractAddress={ens_nft_address}&buyerIsMaker=true"
    headers = {"accept": "application/json"}
    response = requests.get(url, headers=headers)
    returned_sales_df = pd.DataFrame(response.json()['nftSales'])
    nft_sales_df = nft_sales_df.append(returned_sales_df)
    
    newBlockNumber = response.json()['nftSales'][-1]['blockNumber']
    newLogIndex = response.json()['nftSales'][-1]['logIndex']
print('done.')
# Out:
# startBlock = 6880054
# latestBlock = 15640054
# block 15009916 / 15640054 (92.80664383561644% done)
# block 15052650 / 15640054 (93.29447488584475% done)
# block 15094948 / 15640054 (93.7773287671233% done)
# block 15137079 / 15640054 (94.25827625570776% done)
# block 15179348 / 15640054 (94.74079908675799% done)
# block 15221389 / 15640054 (95.22071917808219% done)
# block 15263547 / 15640054 (95.70197488584475% done)
# block 15305987 / 15640054 (96.1864497716895% done)
# block 15348084 / 15640054 (96.66700913242009% done)
# block 15390296 / 15640054 (97.14888127853881% done)
# block 15432536 / 15640054 (97.63107305936073% done)
# block 15474611 / 15640054 (98.11138127853881% done)
# block 15516791 / 15640054 (98.59288812785388% done)
# block 15558930 / 15640054 (99.07392694063927% done)
# block 15601133 / 15640054 (99.55569634703197% done)
# done.

# %%
# # NOTE possibly missing earlier data
# # startBlock = 6880054 # 4 years ago
# # latestBlock = 15640054
# # block 15009916 / 15640054 (92.80664383561644% done) # first finishd chunk of blocks, seems to skip ~90% of early blocks

# save result of loop
nft_sales_df.to_pickle(path = '/Users/macstrelioff/Documents/git/crypto_public/ENS NFT analyses/nft_sales_df')

# %%
# load the saved result instead of re-running code above
# nft_sales_df = pd.read_pickle('nft_sales_df')
